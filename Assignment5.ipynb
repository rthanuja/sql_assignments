# %%
import pandas as pd
from sqlalchemy import create_engine
connection=create_engine('mysql+mysqlconnector://root:Mysql@localhost:3306/Ineuron')
engine=connection.connect()

# %%
#Q-1. Write an SQL query to print details of workers excluding first names, “Vipul” and “Satish” from Worker table.
query="select * from worker where first_name not in ('Vipul','Satish');"
df=pd.read_sql(query,engine)
df
# Out:
#     ID   FIRST_NAME  LAST_NAME                          EMAIL DEPARTMENT  \
# 0    1         John        Doe             john.doe@email.com         HR
# 1    2         Jane      Smith           jane.smith@email.com         IT
# 2    3      Michael    Johnson      michael.johnson@email.com    Finance
# 3    4        Alice   Williams       alice.williams@email.com  Marketing
# 4    5       Robert      Brown         robert.brown@email.com      Sales
# 5    6     Samantha      Davis       samantha.davis@email.com         IT
# 6    7       Daniel     Taylor        daniel.taylor@email.com         HR
# 7    8        Emily   Anderson       emily.anderson@email.com    Finance
# 8    9      Matthew      Clark        matthew.clark@email.com      Sales
# 9   10       Olivia      Moore         olivia.moore@email.com  Marketing
# 10  11        James      Jones          james.jones@email.com         IT
# 11  12         Emma       Hall            emma.hall@email.com    Finance
# ...

# %%
#Q-2. Write an SQL query to print details of the Workers whose FIRST_NAME ends with ‘h’ and contains six alphabets.
query="select * from worker where first_name like '_____h';"
df=pd.read_sql(query,engine)
df
# Out:
#    ID FIRST_NAME LAST_NAME                   EMAIL DEPARTMENT  SALARY  \
# 0  16     Hannah     White  hannah.white@email.com      Sales   69000
# 1  24     Satish     dawan  dawan.satish@email.com  Marketing   75000
#
#     JOIN_DATE
# 0  2013-04-25
# 1  2013-10-25

# %%
#Q-3. Write a query to validate Email of Employee.
query="select email,case when email=concat(lower(first_name),'.',lower(last_name),'@email.com') then 'Valid E=mail' else 'Not valid' end as email_validation from worker ;"
df=pd.read_sql(query,engine)
df
# Out:
#                             email email_validation
# 0              john.doe@email.com     Valid E=mail
# 1            jane.smith@email.com     Valid E=mail
# 2       michael.johnson@email.com     Valid E=mail
# 3        alice.williams@email.com     Valid E=mail
# 4          robert.brown@email.com     Valid E=mail
# 5        samantha.davis@email.com     Valid E=mail
# 6         daniel.taylor@email.com     Valid E=mail
# 7        emily.anderson@email.com     Valid E=mail
# 8         matthew.clark@email.com     Valid E=mail
# 9          olivia.moore@email.com     Valid E=mail
# 10          james.jones@email.com     Valid E=mail
# 11            emma.hall@email.com     Valid E=mail
# 12  christopher.johnson@email.com     Valid E=mail
# 13        amitabh.kumar@email.com     Valid E=mail
# 14     brandon.martinez@email.com     Valid E=mail
# 15         hannah.white@email.com     Valid E=mail
# 16     andrew.rodriguez@email.com     Valid E=mail
# ...

# %%
engine.close()
