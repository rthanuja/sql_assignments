# %%
import pandas as pd
from sqlalchemy import create_engine
connection=create_engine('mysql+mysqlconnector://root:Mysql@localhost:3306/Ineuron')
engine=connection.connect()

# %%
#Q-13. Write an SQL query to show only odd rows from a table.
query="select * from (SELECT *,ROW_NUMBER() OVER (ORDER BY (SELECT NULL)) AS RowNum FROM worker) as new where rownum%2<>0; ;"
df=pd.read_sql(query,engine)
df
# Out:
#     ID   FIRST_NAME  LAST_NAME                          EMAIL DEPARTMENT  \
# 0    1         John        Doe             john.doe@email.com         HR
# 1    3      Michael    Johnson      michael.johnson@email.com    Finance
# 2    5       Robert      Brown         robert.brown@email.com      Sales
# 3    7       Daniel     Taylor        daniel.taylor@email.com         HR
# 4    9      Matthew      Clark        matthew.clark@email.com      Sales
# 5   11        James      Jones          james.jones@email.com         IT
# 6   13  Christopher    Johnson  christopher.johnson@email.com  Marketing
# 7   15      Brandon   Martinez     brandon.martinez@email.com    Finance
# 8   17       Andrew  Rodriguez     andrew.rodriguez@email.com  Marketing
# 9   19      William      Lopez        william.lopez@email.com    Finance
# 10  21       Nathan       Hall          nathan.hall@email.com         IT
# 11  23        Vipul      menon          vipul.menon@email.com         IT
#
# ...

# %%
#Q-14. Write an SQL query to clone a new table from another table.
query="create table if not exists worker_clone as select * from worker;"
engine.execute(query)
df=pd.read_sql("show tables",engine)
df
# Out:
#   Tables_in_ineuron
# 0            worker
# 1      worker_clone

# %%
engine.close()
