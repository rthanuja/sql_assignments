# %%
import pandas as pd
from sqlalchemy import create_engine
connection=create_engine('mysql+mysqlconnector://root:Mysql@localhost:3306/Ineuron')
engine=connection.connect()

# %%
#Q-1. Write an SQL query to print the FIRST_NAME from Worker table after replacing ‘a’ with ‘A’.
query="select replace(first_name,'a','A') as first_name from worker;"
df=pd.read_sql(query,engine)
df
# Out:
#      first_name
# 0          John
# 1          JAne
# 2       MichAel
# 3         Alice
# 4        Robert
# 5      SAmAnthA
# 6        DAniel
# 7         Emily
# 8       MAtthew
# 9        OliviA
# 10        JAmes
# 11         EmmA
# 12  Christopher
# 13      AmitAbh
# 14      BrAndon
# 15       HAnnAh
# 16       Andrew
# 17       SophiA
# 18      WilliAm
# 19         EllA
# 20       NAthAn
# 21          MiA
# 22        Vipul
# 23       SAtish

# %%
#Q-2. Write an SQL query to print all Worker details from the Worker table order by FIRST_NAME Ascending and DEPARTMENT 
#Descending.
query="select * from worker order by first_name asc,department desc;"
df=pd.read_sql(query,engine)
df
# Out:
#     ID   FIRST_NAME  LAST_NAME                          EMAIL DEPARTMENT  \
# 0    4        Alice   Williams       alice.williams@email.com  Marketing
# 1   14      Amitabh      kumar        amitabh.kumar@email.com         IT
# 2   17       Andrew  Rodriguez     andrew.rodriguez@email.com  Marketing
# 3   15      Brandon   Martinez     brandon.martinez@email.com    Finance
# 4   13  Christopher    Johnson  christopher.johnson@email.com  Marketing
# 5    7       Daniel     Taylor        daniel.taylor@email.com         HR
# 6   20         Ella        Lee             ella.lee@email.com      Sales
# 7    8        Emily   Anderson       emily.anderson@email.com    Finance
# 8   12         Emma       Hall            emma.hall@email.com    Finance
# 9   16       Hannah      White         hannah.white@email.com      Sales
# 10  11        James      Jones          james.jones@email.com         IT
# 11   2         Jane      Smith           jane.smith@email.com         IT
# ...

# %%
#Q-3. Write an SQL query to fetch the names of workers who earn the highest salary.
query="select concat(First_name,' ',last_name) as Name, Salary FROM Worker WHERE Salary = (SELECT MAX(Salary) FROM Worker);"
df=pd.read_sql(query,engine)
df
# Out:
#              Name  Salary
# 0  Samantha Davis   90000

# %%
engine.close()
