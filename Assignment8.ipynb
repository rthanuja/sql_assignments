# %%
import pandas as pd
from sqlalchemy import create_engine
connection=create_engine('mysql+mysqlconnector://root:Mysql@localhost:3306/Ineuron')
engine=connection.connect()

# %%
#Q-15. Write an SQL query to fetch intersecting records of two tables.
query="select * from worker intersect SELECT * from worker_clone;"
df=pd.read_sql(query,engine)
df
# Out:
#     ID   FIRST_NAME  LAST_NAME                          EMAIL DEPARTMENT  \
# 0    1         John        Doe             john.doe@email.com         HR
# 1    2         Jane      Smith           jane.smith@email.com         IT
# 2    3      Michael    Johnson      michael.johnson@email.com    Finance
# 3    4        Alice   Williams       alice.williams@email.com  Marketing
# 4    5       Robert      Brown         robert.brown@email.com      Sales
# 5    6     Samantha      Davis       samantha.davis@email.com         IT
# 6    7       Daniel     Taylor        daniel.taylor@email.com         HR
# 7    8        Emily   Anderson       emily.anderson@email.com    Finance
# 8    9      Matthew      Clark        matthew.clark@email.com      Sales
# 9   10       Olivia      Moore         olivia.moore@email.com  Marketing
# 10  11        James      Jones          james.jones@email.com         IT
# 11  12         Emma       Hall            emma.hall@email.com    Finance
# ...

# %%
query="""INSERT INTO worker ( First_Name, Last_Name, Email, Department, Salary, Join_Date)
VALUES
    ( 'John', 'Doe', 'john.doe@example.com', 'IT', 60000, '2022-01-01'),
    ('Jane', 'Smith', 'jane.smith@example.com', 'HR', 55000, '2022-02-15'),
    ( 'Mike', 'Johnson', 'mike.johnson@example.com', 'Finance', 70000, '2022-03-30'),
    ( 'Emily', 'Williams', 'emily.williams@example.com', 'Marketing', 60000, '2022-04-10'),
    ('David', 'Brown', 'david.brown@example.com', 'Sales', 65000, '2022-05-20');"""
engine.execute(query)

# %%
#Q-16. Write an SQL query to show records from one table that another table does not have
query="SELECT * FROM worker as w WHERE NOT EXISTS (SELECT * FROM Worker_clone as wc WHERE w.id=wc.id);"
df=pd.read_sql(query,engine)
df
# Out:
#    ID FIRST_NAME LAST_NAME                       EMAIL DEPARTMENT  SALARY  \
# 0  42       John       Doe        john.doe@example.com         IT   60000
# 1  43       Jane     Smith      jane.smith@example.com         HR   55000
# 2  44       Mike   Johnson    mike.johnson@example.com    Finance   70000
# 3  45      Emily  Williams  emily.williams@example.com  Marketing   60000
# 4  46      David     Brown     david.brown@example.com      Sales   65000
#
#     JOIN_DATE
# 0  2022-01-01
# 1  2022-02-15
# 2  2022-03-30
# 3  2022-04-10
# 4  2022-05-20

# %%
engine.close()
